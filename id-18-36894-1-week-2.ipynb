# %% [markdown]
# *

# %% [markdown]
# tanvir rahman tarafder 18-36894-1

# %%
len([5, 6, 7])

# %%
[5, 6, 7] + [9, 3, 2]

# %%
['Ni!'] * 3

# %%
3 in [4, 5, 6]

# %%
for x in [1,2,3]: print (x)

# %%
str([3, 5]) + "34"

# %%
[2, 3] + list("34")

# %%
L = ['spam', 'Spam', 'SPAM!']
L[1]

# %%
L[-2]

# %%
L[1:]

# %%
matrix = [[1,2,3],[4,5,3],[11,12,13]]

# %%
matrix[1]

# %%
matrix[1][2]

# %%
matrix[2][0]

# %%
matrix = [[1,2,8],
         [5,3,2],
         [7,8,9]]

# %%
matrix[1][2]

# %%
L = ['sp','green','cold']

# %%
L[1] = 'M'

# %%
L

# %%
L[0:2] = ['ant', 'm']

# %%
L

# %%
L.append('sorry')

# %%
L

# %%
L.sort( )

# %%
L

# %%
L = [3, 4]

# %%
L.extend([5,6,7])

# %%
L

# %%
L.pop( )

# %%
L

# %%
L.reverse( )

# %%
L

# %%
L = []
L.append(1)
L.append(2)
L

# %%
L.pop( )

# %%
L

# %%
L

# %%
del L[0]

# %%
L = ['Al', 'gt', 'on']

# %%
L[1:] = []

# %%
L

# %%
L[0] = []
L

# %%
d2 = {'sm': 2, 'hm': 1, 'lgs': 3}

# %%
d2['sm']

# %%
d2

# %%
len(d2)

# %%
d2.has_key('hm')

# %%
'ham' in d2

# %%
d2.keys( )

# %%
d2['ham'] = ['g', 'b', 'f']

# %%
d2

# %%
del d2['eggs']

# %%
d2

# %%
d2['brunch'] = 'B'

# %%
d2

# %%
d2 = {'lam': 3, 'yeam': 1, 'eggs': 4}

# %%
d2.values( )

# %%
d2.items( )

# %%
d2.get('spam')

# %%
d2.get('toast')

# %%
d2.get('toast', 77)

# %%
d2

# %%
d3 = {'roast':2, 'tiffin':3}

# %%
d2.update(d3)

# %%
d2

# %%
d2

# %%
d2.pop('tiffin')

# %%
d2.pop('roast')

# %%
d2

# %%
L = ['aa', 'bb', 'cc', 'dd']

# %%
L.pop( )

# %%
L
